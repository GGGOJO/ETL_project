# %% [markdown]
# # Extract and Transform in preparation to Load in to Postgresql

# %% [markdown]
# ## Data Set No. 1: Bureau of Labor Statistics 2018 SOC Codes
# Standard Occupational Classification System = SOC
# https://www.bls.gov/soc/
# The federal statistical standard used by federal agenices to classify workers in occupational categories for the purpose of collecting, calculating, or disseminating data. Workers are classifed in one of:
# <ul>
# <li> 867 detailed occupations</li>
# <li> 459 broad occupations</li>
# <li> 98 minor groups</li>
# <li> 23 major groups</li> </ul>
# The SOC is updated typically every 10 years
#
# Data table available:
# https://www.bls.gov/soc/2018/soc_structure_2018.xlsx<br>
# .xlxs file |
# version 2018 |
# downloaded March 14, 2021 |
# 1,447 records

# %%
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy import create_engine

# EXTRACT: a file into jupyter notebook (Remember to Change These According to the Path)
# Read soc data file and store into Pandas DataFrames
soc_df = pd.read_excel('./Resources/soc_2018_definitions.xlsx')

soc_df.head(30)
# Out:
#                       U.S. Bureau of Labor Statistics Unnamed: 1  \
# 0   On behalf of the Office of Management and Budg...        NaN
# 1                                                 NaN        NaN
# 2   November 2017 (for reference year January 2018...        NaN
# 3   ***This is the final structure and detailed de...        NaN
# 4                                                 NaN        NaN
# 5                                                 NaN        NaN
# 6                                           SOC Group   SOC Code
# 7                                               Major    11-0000
# 8                                               Minor    11-1000
# 9                                               Broad    11-1010
# 10                                           Detailed    11-1011
# 11                                              Broad    11-1020
# 12                                           Detailed    11-1021
# 13                                              Broad    11-1030
# 14                                           Detailed    11-1031
# 15                                              Minor    11-2000
# 16                                              Broad    11-2010
# 17                                           Detailed    11-2011
# 18                                              Broad    11-2020
# 19                                           Detailed    11-2021
# 20                                           Detailed    11-2022
# 21                                              Broad    11-2030
# 22                                           Detailed    11-2032
# 23                                           Detailed    11-2033
# 24                                              Minor    11-3000
# 25                                              Broad    11-3010
# 26                                           Detailed    11-3012
# 27                                           Detailed    11-3013
# 28                                              Broad    11-3020
# 29                                           Detailed    11-3021
#
#                                            Unnamed: 2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                           SOC Title
# 7                              Management Occupations
# 8                                      Top Executives
# 9                                    Chief Executives
# 10                                   Chief Executives
# 11                    General and Operations Managers
# 12                    General and Operations Managers
# 13                                        Legislators
# 14                                        Legislators
# 15  Advertising, Marketing, Promotions, Public Rel...
# 16                Advertising and Promotions Managers
# 17                Advertising and Promotions Managers
# 18                       Marketing and Sales Managers
# 19                                 Marketing Managers
# 20                                     Sales Managers
# 21          Public Relations and Fundraising Managers
# 22                          Public Relations Managers
# 23                               Fundraising Managers
# 24                    Operations Specialties Managers
# 25    Administrative Services and Facilities Managers
# 26                   Administrative Services Managers
# 27                                Facilities Managers
# 28          Computer and Information Systems Managers
# 29          Computer and Information Systems Managers
#
#                                            Unnamed: 3
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                      SOC Definition
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Determine and formulate policies and provide o...
# 11                                                NaN
# 12  Plan, direct, or coordinate the operations of ...
# 13                                                NaN
# 14  Develop, introduce, or enact laws and statutes...
# 15                                                NaN
# 16                                                NaN
# 17  Plan, direct, or coordinate advertising polici...
# 18                                                NaN
# 19  Plan, direct, or coordinate marketing policies...
# 20  Plan, direct, or coordinate the actual distrib...
# 21                                                NaN
# 22  Plan, direct, or coordinate activities designe...
# 23  Plan, direct, or coordinate activities to soli...
# 24                                                NaN
# 25                                                NaN
# 26  Plan, direct, or coordinate one or more admini...
# 27  Plan, direct, or coordinate operations and fun...
# 28                                                NaN
# 29  Plan, direct, or coordinate activities in such...

# %%
# TRANSFORM: Begin the process of clearning
# Drop the extra rows of text (not header)
soc_df = soc_df.drop([0,1,2,3,4,5,6])
soc_df.head(30)
# Out:
#    U.S. Bureau of Labor Statistics Unnamed: 1  \
# 7                            Major    11-0000
# 8                            Minor    11-1000
# 9                            Broad    11-1010
# 10                        Detailed    11-1011
# 11                           Broad    11-1020
# 12                        Detailed    11-1021
# 13                           Broad    11-1030
# 14                        Detailed    11-1031
# 15                           Minor    11-2000
# 16                           Broad    11-2010
# 17                        Detailed    11-2011
# 18                           Broad    11-2020
# 19                        Detailed    11-2021
# 20                        Detailed    11-2022
# 21                           Broad    11-2030
# 22                        Detailed    11-2032
# 23                        Detailed    11-2033
# 24                           Minor    11-3000
# 25                           Broad    11-3010
# 26                        Detailed    11-3012
# 27                        Detailed    11-3013
# 28                           Broad    11-3020
# 29                        Detailed    11-3021
# 30                           Broad    11-3030
# 31                        Detailed    11-3031
# 32                           Broad    11-3050
# 33                        Detailed    11-3051
# 34                           Broad    11-3060
# 35                        Detailed    11-3061
# 36                           Broad    11-3070
#
#                                            Unnamed: 2  \
# 7                              Management Occupations
# 8                                      Top Executives
# 9                                    Chief Executives
# 10                                   Chief Executives
# 11                    General and Operations Managers
# 12                    General and Operations Managers
# 13                                        Legislators
# 14                                        Legislators
# 15  Advertising, Marketing, Promotions, Public Rel...
# 16                Advertising and Promotions Managers
# 17                Advertising and Promotions Managers
# 18                       Marketing and Sales Managers
# 19                                 Marketing Managers
# 20                                     Sales Managers
# 21          Public Relations and Fundraising Managers
# 22                          Public Relations Managers
# 23                               Fundraising Managers
# 24                    Operations Specialties Managers
# 25    Administrative Services and Facilities Managers
# 26                   Administrative Services Managers
# 27                                Facilities Managers
# 28          Computer and Information Systems Managers
# 29          Computer and Information Systems Managers
# 30                                 Financial Managers
# 31                                 Financial Managers
# 32                     Industrial Production Managers
# 33                     Industrial Production Managers
# 34                                Purchasing Managers
# 35                                Purchasing Managers
# 36  Transportation, Storage, and Distribution Mana...
#
#                                            Unnamed: 3
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Determine and formulate policies and provide o...
# 11                                                NaN
# 12  Plan, direct, or coordinate the operations of ...
# 13                                                NaN
# 14  Develop, introduce, or enact laws and statutes...
# 15                                                NaN
# 16                                                NaN
# 17  Plan, direct, or coordinate advertising polici...
# 18                                                NaN
# 19  Plan, direct, or coordinate marketing policies...
# 20  Plan, direct, or coordinate the actual distrib...
# 21                                                NaN
# 22  Plan, direct, or coordinate activities designe...
# 23  Plan, direct, or coordinate activities to soli...
# 24                                                NaN
# 25                                                NaN
# 26  Plan, direct, or coordinate one or more admini...
# 27  Plan, direct, or coordinate operations and fun...
# 28                                                NaN
# 29  Plan, direct, or coordinate activities in such...
# 30                                                NaN
# 31  Plan, direct, or coordinate accounting, invest...
# 32                                                NaN
# 33  Plan, direct, or coordinate the work activitie...
# 34                                                NaN
# 35  Plan, direct, or coordinate the activities of ...
# 36                                                NaN

# %%
# Rename the columns
soc_df = soc_df.rename(columns={'U.S. Bureau of Labor Statistics':'level','Unnamed: 1': 'soc_code', 'Unnamed: 2': 'soc_title', 'Unnamed: 3': 'soc_definition' })
soc_df.head()
# Out:
#        level soc_code                        soc_title  \
# 7      Major  11-0000           Management Occupations
# 8      Minor  11-1000                   Top Executives
# 9      Broad  11-1010                 Chief Executives
# 10  Detailed  11-1011                 Chief Executives
# 11     Broad  11-1020  General and Operations Managers
#
#                                        soc_definition
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Determine and formulate policies and provide o...
# 11                                                NaN

# %%
# Reset the index
soc_df.reset_index(drop = True, inplace = False)
# Out:
#          level soc_code                                          soc_title  \
# 0        Major  11-0000                             Management Occupations
# 1        Minor  11-1000                                     Top Executives
# 2        Broad  11-1010                                   Chief Executives
# 3     Detailed  11-1011                                   Chief Executives
# 4        Broad  11-1020                    General and Operations Managers
# ...        ...      ...                                                ...
# 1442  Detailed  55-3014                 Artillery and Missile Crew Members
# 1443  Detailed  55-3015             Command and Control Center Specialists
# 1444  Detailed  55-3016                                           Infantry
# 1445  Detailed  55-3018                                     Special Forces
# 1446  Detailed  55-3019  Military Enlisted Tactical Operations and Air/...
#
#                                          soc_definition
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Determine and formulate policies and provide o...
# 4                                                   NaN
# ...                                                 ...
# 1442  Target, fire, and maintain weapons used to des...
# 1443  Operate and monitor communications, detection,...
# 1444  Operate weapons and equipment in ground combat...
# 1445  Implement unconventional operations by air, la...
# 1446  All military enlisted tactical operations and ...
#
# [1447 rows x 4 columns]

# %%
# For SQL and to get read of the NaN, I decided to split the original table into 4 small tables by 'level'
# Cleaning and normalizing the data

# MAJOR DATAFRAME

major_soc_df = soc_df.loc[soc_df.level=='Major']
major_soc_df
# Out:
#       level soc_code                                          soc_title  \
# 7     Major  11-0000                             Management Occupations
# 80    Major  13-0000      Business and Financial Operations Occupations
# 141   Major  15-0000              Computer and Mathematical Occupations
# 177   Major  17-0000           Architecture and Engineering Occupations
# 238   Major  19-0000     Life, Physical, and Social Science Occupations
# 317   Major  21-0000           Community and Social Service Occupations
# 344   Major  23-0000                                  Legal Occupations
# 359   Major  25-0000    Educational Instruction and Library Occupations
# 459   Major  27-0000  Arts, Design, Entertainment, Sports, and Media...
# 521   Major  29-0000  Healthcare Practitioners and Technical Occupat...
# 624   Major  31-0000                     Healthcare Support Occupations
# 652   Major  33-0000                     Protective Service Occupations
# 695   Major  35-0000   Food Preparation and Serving Related Occupations
# 728   Major  37-0000  Building and Grounds Cleaning and Maintenance ...
# 746   Major  39-0000              Personal Care and Service Occupations
# 807   Major  41-0000                      Sales and Related Occupations
# 850   Major  43-0000      Office and Administrative Support Occupations
# 959   Major  45-0000         Farming, Fishing, and Forestry Occupations
# 986   Major  47-0000            Construction and Extraction Occupations
# 1090  Major  49-0000  Installation, Maintenance, and Repair Occupations
# 1165  Major  51-0000                             Production Occupations
# 1334  Major  53-0000     Transportation and Material Moving Occupations
# 1428  Major  55-0000                      Military Specific Occupations
#
#      soc_definition
# 7               NaN
# 80              NaN
# 141             NaN
# 177             NaN
# 238             NaN
# 317             NaN
# 344             NaN
# 359             NaN
# 459             NaN
# 521             NaN
# 624             NaN
# 652             NaN
# 695             NaN
# 728             NaN
# 746             NaN
# 807             NaN
# 850             NaN
# 959             NaN
# 986             NaN
# 1090            NaN
# 1165            NaN
# 1334            NaN
# 1428            NaN

# %%
# MAJOR DATAFRAME
# reset index
major_soc_df = major_soc_df.reset_index(drop = True, inplace = False)
major_soc_df
# Out:
#     level soc_code                                          soc_title  \
# 0   Major  11-0000                             Management Occupations
# 1   Major  13-0000      Business and Financial Operations Occupations
# 2   Major  15-0000              Computer and Mathematical Occupations
# 3   Major  17-0000           Architecture and Engineering Occupations
# 4   Major  19-0000     Life, Physical, and Social Science Occupations
# 5   Major  21-0000           Community and Social Service Occupations
# 6   Major  23-0000                                  Legal Occupations
# 7   Major  25-0000    Educational Instruction and Library Occupations
# 8   Major  27-0000  Arts, Design, Entertainment, Sports, and Media...
# 9   Major  29-0000  Healthcare Practitioners and Technical Occupat...
# 10  Major  31-0000                     Healthcare Support Occupations
# 11  Major  33-0000                     Protective Service Occupations
# 12  Major  35-0000   Food Preparation and Serving Related Occupations
# 13  Major  37-0000  Building and Grounds Cleaning and Maintenance ...
# 14  Major  39-0000              Personal Care and Service Occupations
# 15  Major  41-0000                      Sales and Related Occupations
# 16  Major  43-0000      Office and Administrative Support Occupations
# 17  Major  45-0000         Farming, Fishing, and Forestry Occupations
# 18  Major  47-0000            Construction and Extraction Occupations
# 19  Major  49-0000  Installation, Maintenance, and Repair Occupations
# 20  Major  51-0000                             Production Occupations
# 21  Major  53-0000     Transportation and Material Moving Occupations
# 22  Major  55-0000                      Military Specific Occupations
#
#    soc_definition
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN

# %%
# MAJOR DATAFRAME
# Drop this column because it's all NaN
major_soc_df = major_soc_df.drop(columns = {'soc_definition', 'level'})
major_soc_df
# Out:
#    soc_code                                          soc_title
# 0   11-0000                             Management Occupations
# 1   13-0000      Business and Financial Operations Occupations
# 2   15-0000              Computer and Mathematical Occupations
# 3   17-0000           Architecture and Engineering Occupations
# 4   19-0000     Life, Physical, and Social Science Occupations
# 5   21-0000           Community and Social Service Occupations
# 6   23-0000                                  Legal Occupations
# 7   25-0000    Educational Instruction and Library Occupations
# 8   27-0000  Arts, Design, Entertainment, Sports, and Media...
# 9   29-0000  Healthcare Practitioners and Technical Occupat...
# 10  31-0000                     Healthcare Support Occupations
# 11  33-0000                     Protective Service Occupations
# 12  35-0000   Food Preparation and Serving Related Occupations
# 13  37-0000  Building and Grounds Cleaning and Maintenance ...
# 14  39-0000              Personal Care and Service Occupations
# 15  41-0000                      Sales and Related Occupations
# 16  43-0000      Office and Administrative Support Occupations
# 17  45-0000         Farming, Fishing, and Forestry Occupations
# 18  47-0000            Construction and Extraction Occupations
# 19  49-0000  Installation, Maintenance, and Repair Occupations
# 20  51-0000                             Production Occupations
# 21  53-0000     Transportation and Material Moving Occupations
# 22  55-0000                      Military Specific Occupations

# %%
major_soc_df = major_soc_df.rename(columns = {'soc_title': 'major_title'})
major_soc_df.head()
# Out:
#   soc_code                                     major_title
# 0  11-0000                          Management Occupations
# 1  13-0000   Business and Financial Operations Occupations
# 2  15-0000           Computer and Mathematical Occupations
# 3  17-0000        Architecture and Engineering Occupations
# 4  19-0000  Life, Physical, and Social Science Occupations

# %%
major_soc_df.dtypes
# Out:
# soc_code       object
# major_title    object
# dtype: object

# %%
#MINOR DATAFRAME

minor_soc_df = soc_df.loc[soc_df.level=='Minor']
minor_soc_df
# Out:
#       level soc_code                                          soc_title  \
# 8     Minor  11-1000                                     Top Executives
# 15    Minor  11-2000  Advertising, Marketing, Promotions, Public Rel...
# 24    Minor  11-3000                    Operations Specialties Managers
# 44    Minor  11-9000                       Other Management Occupations
# 81    Minor  13-1000                    Business Operations Specialists
# ...     ...      ...                                                ...
# 1385  Minor  53-6000                       Other Transportation Workers
# 1401  Minor  53-7000                            Material Moving Workers
# 1429  Minor  55-1000  Military Officer Special and Tactical Operatio...
# 1439  Minor  55-2000           First-Line Enlisted Military Supervisors
# 1444  Minor  55-3000  Military Enlisted Tactical Operations and Air/...
#
#      soc_definition
# 8               NaN
# 15              NaN
# 24              NaN
# 44              NaN
# 81              NaN
# ...             ...
# 1385            NaN
# 1401            NaN
# 1429            NaN
# 1439            NaN
# 1444            NaN
#
# [98 rows x 4 columns]

# %%
# MINOR DATAFRAME
# reset index
minor_soc_df = minor_soc_df.reset_index(drop = True, inplace = False)
minor_soc_df
# Out:
#     level soc_code                                          soc_title  \
# 0   Minor  11-1000                                     Top Executives
# 1   Minor  11-2000  Advertising, Marketing, Promotions, Public Rel...
# 2   Minor  11-3000                    Operations Specialties Managers
# 3   Minor  11-9000                       Other Management Occupations
# 4   Minor  13-1000                    Business Operations Specialists
# ..    ...      ...                                                ...
# 93  Minor  53-6000                       Other Transportation Workers
# 94  Minor  53-7000                            Material Moving Workers
# 95  Minor  55-1000  Military Officer Special and Tactical Operatio...
# 96  Minor  55-2000           First-Line Enlisted Military Supervisors
# 97  Minor  55-3000  Military Enlisted Tactical Operations and Air/...
#
#    soc_definition
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 93            NaN
# 94            NaN
# 95            NaN
# 96            NaN
# 97            NaN
#
# [98 rows x 4 columns]

# %%
# MINOR DATAFRAME
# Drop this column because it's all NaN
minor_soc_df = minor_soc_df.drop(columns = {'soc_definition', 'level'})
minor_soc_df
# Out:
#    soc_code                                          soc_title
# 0   11-1000                                     Top Executives
# 1   11-2000  Advertising, Marketing, Promotions, Public Rel...
# 2   11-3000                    Operations Specialties Managers
# 3   11-9000                       Other Management Occupations
# 4   13-1000                    Business Operations Specialists
# ..      ...                                                ...
# 93  53-6000                       Other Transportation Workers
# 94  53-7000                            Material Moving Workers
# 95  55-1000  Military Officer Special and Tactical Operatio...
# 96  55-2000           First-Line Enlisted Military Supervisors
# 97  55-3000  Military Enlisted Tactical Operations and Air/...
#
# [98 rows x 2 columns]

# %%
minor_soc_df = minor_soc_df.rename(columns = {'soc_title': 'minor_title'})
minor_soc_df.head()
# Out:
#   soc_code                                        minor_title
# 0  11-1000                                     Top Executives
# 1  11-2000  Advertising, Marketing, Promotions, Public Rel...
# 2  11-3000                    Operations Specialties Managers
# 3  11-9000                       Other Management Occupations
# 4  13-1000                    Business Operations Specialists

# %%
minor_soc_df.dtypes
# Out:
# soc_code       object
# minor_title    object
# dtype: object

# %%
# BROAD DATAFRAME
broad_soc_df = soc_df.loc[soc_df.level=='Broad']
broad_soc_df
# Out:
#       level soc_code                                          soc_title  \
# 9     Broad  11-1010                                   Chief Executives
# 11    Broad  11-1020                    General and Operations Managers
# 13    Broad  11-1030                                        Legislators
# 16    Broad  11-2010                Advertising and Promotions Managers
# 18    Broad  11-2020                       Marketing and Sales Managers
# ...     ...      ...                                                ...
# 1424  Broad  53-7120                  Tank Car, Truck, and Ship Loaders
# 1426  Broad  53-7190              Miscellaneous Material Moving Workers
# 1430  Broad  55-1010  Military Officer Special and Tactical Operatio...
# 1440  Broad  55-2010           First-Line Enlisted Military Supervisors
# 1445  Broad  55-3010  Military Enlisted Tactical Operations and Air/...
#
#      soc_definition
# 9               NaN
# 11              NaN
# 13              NaN
# 16              NaN
# 18              NaN
# ...             ...
# 1424            NaN
# 1426            NaN
# 1430            NaN
# 1440            NaN
# 1445            NaN
#
# [459 rows x 4 columns]

# %%
# BROAD DATAFRAME
# reset index
broad_soc_df = broad_soc_df.reset_index(drop = True, inplace = False)
broad_soc_df
# Out:
#      level soc_code                                          soc_title  \
# 0    Broad  11-1010                                   Chief Executives
# 1    Broad  11-1020                    General and Operations Managers
# 2    Broad  11-1030                                        Legislators
# 3    Broad  11-2010                Advertising and Promotions Managers
# 4    Broad  11-2020                       Marketing and Sales Managers
# ..     ...      ...                                                ...
# 454  Broad  53-7120                  Tank Car, Truck, and Ship Loaders
# 455  Broad  53-7190              Miscellaneous Material Moving Workers
# 456  Broad  55-1010  Military Officer Special and Tactical Operatio...
# 457  Broad  55-2010           First-Line Enlisted Military Supervisors
# 458  Broad  55-3010  Military Enlisted Tactical Operations and Air/...
#
#     soc_definition
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 454            NaN
# 455            NaN
# 456            NaN
# 457            NaN
# 458            NaN
#
# [459 rows x 4 columns]

# %%
# BROAD DATAFRAME
# Drop this column because it's all NaN

broad_soc_df = broad_soc_df.drop(columns = {'soc_definition', 'level'})
broad_soc_df
# Out:
#     soc_code                                          soc_title
# 0    11-1010                                   Chief Executives
# 1    11-1020                    General and Operations Managers
# 2    11-1030                                        Legislators
# 3    11-2010                Advertising and Promotions Managers
# 4    11-2020                       Marketing and Sales Managers
# ..       ...                                                ...
# 454  53-7120                  Tank Car, Truck, and Ship Loaders
# 455  53-7190              Miscellaneous Material Moving Workers
# 456  55-1010  Military Officer Special and Tactical Operatio...
# 457  55-2010           First-Line Enlisted Military Supervisors
# 458  55-3010  Military Enlisted Tactical Operations and Air/...
#
# [459 rows x 2 columns]

# %%
broad_soc_df = broad_soc_df.rename(columns = {'soc_title': 'broad_title'})
broad_soc_df.head()
# Out:
#   soc_code                          broad_title
# 0  11-1010                     Chief Executives
# 1  11-1020      General and Operations Managers
# 2  11-1030                          Legislators
# 3  11-2010  Advertising and Promotions Managers
# 4  11-2020         Marketing and Sales Managers

# %%
broad_soc_df.dtypes
# Out:
# soc_code       object
# broad_title    object
# dtype: object

# %%
# DETAILED DATAFRAME

detailed_soc_df = soc_df.loc[soc_df.level=='Detailed']
detailed_soc_df
# Out:
#          level soc_code                                          soc_title  \
# 10    Detailed  11-1011                                   Chief Executives
# 12    Detailed  11-1021                    General and Operations Managers
# 14    Detailed  11-1031                                        Legislators
# 17    Detailed  11-2011                Advertising and Promotions Managers
# 19    Detailed  11-2021                                 Marketing Managers
# ...        ...      ...                                                ...
# 1449  Detailed  55-3014                 Artillery and Missile Crew Members
# 1450  Detailed  55-3015             Command and Control Center Specialists
# 1451  Detailed  55-3016                                           Infantry
# 1452  Detailed  55-3018                                     Special Forces
# 1453  Detailed  55-3019  Military Enlisted Tactical Operations and Air/...
#
#                                          soc_definition
# 10    Determine and formulate policies and provide o...
# 12    Plan, direct, or coordinate the operations of ...
# 14    Develop, introduce, or enact laws and statutes...
# 17    Plan, direct, or coordinate advertising polici...
# 19    Plan, direct, or coordinate marketing policies...
# ...                                                 ...
# 1449  Target, fire, and maintain weapons used to des...
# 1450  Operate and monitor communications, detection,...
# 1451  Operate weapons and equipment in ground combat...
# 1452  Implement unconventional operations by air, la...
# 1453  All military enlisted tactical operations and ...
#
# [867 rows x 4 columns]

# %%
# DETAILED DATAFRAME
# reset index

detailed_soc_df = detailed_soc_df.reset_index(drop = True, inplace = False)
detailed_soc_df
# Out:
#         level soc_code                                          soc_title  \
# 0    Detailed  11-1011                                   Chief Executives
# 1    Detailed  11-1021                    General and Operations Managers
# 2    Detailed  11-1031                                        Legislators
# 3    Detailed  11-2011                Advertising and Promotions Managers
# 4    Detailed  11-2021                                 Marketing Managers
# ..        ...      ...                                                ...
# 862  Detailed  55-3014                 Artillery and Missile Crew Members
# 863  Detailed  55-3015             Command and Control Center Specialists
# 864  Detailed  55-3016                                           Infantry
# 865  Detailed  55-3018                                     Special Forces
# 866  Detailed  55-3019  Military Enlisted Tactical Operations and Air/...
#
#                                         soc_definition
# 0    Determine and formulate policies and provide o...
# 1    Plan, direct, or coordinate the operations of ...
# 2    Develop, introduce, or enact laws and statutes...
# 3    Plan, direct, or coordinate advertising polici...
# 4    Plan, direct, or coordinate marketing policies...
# ..                                                 ...
# 862  Target, fire, and maintain weapons used to des...
# 863  Operate and monitor communications, detection,...
# 864  Operate weapons and equipment in ground combat...
# 865  Implement unconventional operations by air, la...
# 866  All military enlisted tactical operations and ...
#
# [867 rows x 4 columns]

# %%
# DETAILED DATAFRAME
# drop 'level' because it is not necessary
detailed_soc_df = detailed_soc_df.drop(columns = 'level')
detailed_soc_df
# Out:
#     soc_code                                          soc_title  \
# 0    11-1011                                   Chief Executives
# 1    11-1021                    General and Operations Managers
# 2    11-1031                                        Legislators
# 3    11-2011                Advertising and Promotions Managers
# 4    11-2021                                 Marketing Managers
# ..       ...                                                ...
# 862  55-3014                 Artillery and Missile Crew Members
# 863  55-3015             Command and Control Center Specialists
# 864  55-3016                                           Infantry
# 865  55-3018                                     Special Forces
# 866  55-3019  Military Enlisted Tactical Operations and Air/...
#
#                                         soc_definition
# 0    Determine and formulate policies and provide o...
# 1    Plan, direct, or coordinate the operations of ...
# 2    Develop, introduce, or enact laws and statutes...
# 3    Plan, direct, or coordinate advertising polici...
# 4    Plan, direct, or coordinate marketing policies...
# ..                                                 ...
# 862  Target, fire, and maintain weapons used to des...
# 863  Operate and monitor communications, detection,...
# 864  Operate weapons and equipment in ground combat...
# 865  Implement unconventional operations by air, la...
# 866  All military enlisted tactical operations and ...
#
# [867 rows x 3 columns]

# %%
detailed_soc_df = detailed_soc_df.rename(columns = {'soc_title': 'detailed_title', 'soc_definition': 'definition'})
detailed_soc_df.head()
# Out:
#   soc_code                       detailed_title  \
# 0  11-1011                     Chief Executives
# 1  11-1021      General and Operations Managers
# 2  11-1031                          Legislators
# 3  11-2011  Advertising and Promotions Managers
# 4  11-2021                   Marketing Managers
#
#                                           definition
# 0  Determine and formulate policies and provide o...
# 1  Plan, direct, or coordinate the operations of ...
# 2  Develop, introduce, or enact laws and statutes...
# 3  Plan, direct, or coordinate advertising polici...
# 4  Plan, direct, or coordinate marketing policies...

# %%
detailed_soc_df.dtypes
# Out:
# soc_code          object
# detailed_title    object
# definition        object
# dtype: object

# %% [markdown]
# ## Data Set No. 2: ONET Education, Experience, and Training
# Occupational Information Network = ONET
# Asked 6 questions about the education and experience requirements for a job
# https://www.onetcenter.org/dl_files/MS_Word/Education_and_Training.docx
#
# Data available:
# https://www.onetcenter.org/database.html#ete <br>
# .txt file |
# version 25.2 |
# downloaded March 18, 2021 |
# 34,103 records

# %%
# EXTRACT: another file to import into jupyter notebooks (Remember to Change These According to the Path)
# Read O*NET Education, Experience, and Training data file and store into Pandas DataFrames

ed_df = pd.read_csv('./Resources/education_training_experience.txt', delimiter='\t')
ed_df
# Out:
#       O*NET-SOC Code Element ID                 Element Name Scale ID  \
# 0         11-1011.00      2.D.1  Required Level of Education       RL
# 1         11-1011.00      2.D.1  Required Level of Education       RL
# 2         11-1011.00      2.D.1  Required Level of Education       RL
# 3         11-1011.00      2.D.1  Required Level of Education       RL
# 4         11-1011.00      2.D.1  Required Level of Education       RL
# ...              ...        ...                          ...      ...
# 34098     53-7121.00      3.A.3          On-the-Job Training       OJ
# 34099     53-7121.00      3.A.3          On-the-Job Training       OJ
# 34100     53-7121.00      3.A.3          On-the-Job Training       OJ
# 34101     53-7121.00      3.A.3          On-the-Job Training       OJ
# 34102     53-7121.00      3.A.3          On-the-Job Training       OJ
#
#        Category  Data Value   N  Standard Error  Lower CI Bound  \
# 0           1.0        0.00  27            0.00             NaN
# 1           2.0        0.00  27            0.00             NaN
# 2           3.0        0.00  27            0.00             NaN
# 3           4.0        6.05  27            4.43            1.28
# 4           5.0        4.23  27            4.27            0.50
# ...         ...         ...  ..             ...             ...
# 34098       5.0       27.84  27           12.54            9.66
# 34099       6.0       12.27  27            7.21            3.41
# 34100       7.0        1.21  27            1.27            0.14
# 34101       8.0        1.57  27            1.62            0.19
# 34102       9.0        0.00  27            0.00             NaN
#
#        Upper CI Bound Recommend Suppress     Date Domain Source
# 0                 NaN                  N  07/2014     Incumbent
# 1                 NaN                  N  07/2014     Incumbent
# 2                 NaN                  N  07/2014     Incumbent
# 3               24.19                  N  07/2014     Incumbent
# 4               27.80                  N  07/2014     Incumbent
# ...               ...                ...      ...           ...
# 34098           58.19                  N  08/2019     Incumbent
# 34099           35.65                  N  08/2019     Incumbent
# 34100            9.86                  N  08/2019     Incumbent
# 34101           12.05                  N  08/2019     Incumbent
# 34102             NaN                  N  08/2019     Incumbent
#
# [34103 rows x 13 columns]

# %%
# TRANSFORM: Begin the process of cleaning the data
# Identify the columns that I need by dropping the other columns from the dataframe
ed_df = ed_df.drop(columns = {'Category', 'N', 'Standard Error', 'Lower CI Bound', 'Upper CI Bound', 'Recommend Suppress', 'Domain Source'})
ed_df
# Out:
#       O*NET-SOC Code Element ID                 Element Name Scale ID  \
# 0         11-1011.00      2.D.1  Required Level of Education       RL
# 1         11-1011.00      2.D.1  Required Level of Education       RL
# 2         11-1011.00      2.D.1  Required Level of Education       RL
# 3         11-1011.00      2.D.1  Required Level of Education       RL
# 4         11-1011.00      2.D.1  Required Level of Education       RL
# ...              ...        ...                          ...      ...
# 34098     53-7121.00      3.A.3          On-the-Job Training       OJ
# 34099     53-7121.00      3.A.3          On-the-Job Training       OJ
# 34100     53-7121.00      3.A.3          On-the-Job Training       OJ
# 34101     53-7121.00      3.A.3          On-the-Job Training       OJ
# 34102     53-7121.00      3.A.3          On-the-Job Training       OJ
#
#        Data Value     Date
# 0            0.00  07/2014
# 1            0.00  07/2014
# 2            0.00  07/2014
# 3            6.05  07/2014
# 4            4.23  07/2014
# ...           ...      ...
# 34098       27.84  08/2019
# 34099       12.27  08/2019
# 34100        1.21  08/2019
# 34101        1.57  08/2019
# 34102        0.00  08/2019
#
# [34103 rows x 6 columns]

# %%
# If I want to merge this data set with the SOC, transform the O*NET-SOC Code without the .00
test_df = ed_df["O*NET-SOC Code"].str.split(".", n=1, expand = True)

# %%
ed_df["onet_soc_code"]= test_df[0]
ed_df.head()
# Out:
#   O*NET-SOC Code Element ID                 Element Name Scale ID  Data Value  \
# 0     11-1011.00      2.D.1  Required Level of Education       RL        0.00
# 1     11-1011.00      2.D.1  Required Level of Education       RL        0.00
# 2     11-1011.00      2.D.1  Required Level of Education       RL        0.00
# 3     11-1011.00      2.D.1  Required Level of Education       RL        6.05
# 4     11-1011.00      2.D.1  Required Level of Education       RL        4.23
#
#       Date onet_soc_code
# 0  07/2014       11-1011
# 1  07/2014       11-1011
# 2  07/2014       11-1011
# 3  07/2014       11-1011
# 4  07/2014       11-1011

# %%
# Preference to rename the attributes to snake format
ed_df = ed_df.rename(columns={'Element ID': 'ed_id', 'Element Name':'ed_name',
                              'Scale ID':'ed_scale', 'Data Value':'ed_data', 'Date':'ed_date'})
ed_df.head()
# Out:
#   O*NET-SOC Code  ed_id                      ed_name ed_scale  ed_data  \
# 0     11-1011.00  2.D.1  Required Level of Education       RL     0.00
# 1     11-1011.00  2.D.1  Required Level of Education       RL     0.00
# 2     11-1011.00  2.D.1  Required Level of Education       RL     0.00
# 3     11-1011.00  2.D.1  Required Level of Education       RL     6.05
# 4     11-1011.00  2.D.1  Required Level of Education       RL     4.23
#
#    ed_date onet_soc_code
# 0  07/2014       11-1011
# 1  07/2014       11-1011
# 2  07/2014       11-1011
# 3  07/2014       11-1011
# 4  07/2014       11-1011

# %%
# Drop the old O*NET-SOC Code once the split and new attribute was created
ed_df = ed_df.drop(columns = 'O*NET-SOC Code')
ed_df
# Out:
#        ed_id                      ed_name ed_scale  ed_data  ed_date  \
# 0      2.D.1  Required Level of Education       RL     0.00  07/2014
# 1      2.D.1  Required Level of Education       RL     0.00  07/2014
# 2      2.D.1  Required Level of Education       RL     0.00  07/2014
# 3      2.D.1  Required Level of Education       RL     6.05  07/2014
# 4      2.D.1  Required Level of Education       RL     4.23  07/2014
# ...      ...                          ...      ...      ...      ...
# 34098  3.A.3          On-the-Job Training       OJ    27.84  08/2019
# 34099  3.A.3          On-the-Job Training       OJ    12.27  08/2019
# 34100  3.A.3          On-the-Job Training       OJ     1.21  08/2019
# 34101  3.A.3          On-the-Job Training       OJ     1.57  08/2019
# 34102  3.A.3          On-the-Job Training       OJ     0.00  08/2019
#
#       onet_soc_code
# 0           11-1011
# 1           11-1011
# 2           11-1011
# 3           11-1011
# 4           11-1011
# ...             ...
# 34098       53-7121
# 34099       53-7121
# 34100       53-7121
# 34101       53-7121
# 34102       53-7121
#
# [34103 rows x 6 columns]

# %%
# Reorder the columns with onet_soc_code, which will be a primary key across all the data tables

ed_df = ed_df[['onet_soc_code', 'ed_id', 'ed_name', 'ed_scale', 'ed_data', 'ed_date']]
ed_df
# Out:
#       onet_soc_code  ed_id                      ed_name ed_scale  ed_data  \
# 0           11-1011  2.D.1  Required Level of Education       RL     0.00
# 1           11-1011  2.D.1  Required Level of Education       RL     0.00
# 2           11-1011  2.D.1  Required Level of Education       RL     0.00
# 3           11-1011  2.D.1  Required Level of Education       RL     6.05
# 4           11-1011  2.D.1  Required Level of Education       RL     4.23
# ...             ...    ...                          ...      ...      ...
# 34098       53-7121  3.A.3          On-the-Job Training       OJ    27.84
# 34099       53-7121  3.A.3          On-the-Job Training       OJ    12.27
# 34100       53-7121  3.A.3          On-the-Job Training       OJ     1.21
# 34101       53-7121  3.A.3          On-the-Job Training       OJ     1.57
# 34102       53-7121  3.A.3          On-the-Job Training       OJ     0.00
#
#        ed_date
# 0      07/2014
# 1      07/2014
# 2      07/2014
# 3      07/2014
# 4      07/2014
# ...        ...
# 34098  08/2019
# 34099  08/2019
# 34100  08/2019
# 34101  08/2019
# 34102  08/2019
#
# [34103 rows x 6 columns]

# %%
ed_df.dtypes
# Out:
# onet_soc_code     object
# ed_id             object
# ed_name           object
# ed_scale          object
# ed_data          float64
# ed_date           object
# dtype: object

# %% [markdown]
# ## Data Set No. 3: ONET Occupational Skills
# Occupational Information Network = ONET
# Skills
# * Basic
# * Complex Problem Solving
# * Resource Management
# * Social Skills
# * Systems
# * Technical
#
# https://www.onetcenter.org/dictionary/25.2/excel/skills.html <br>
# .txt file |
# version 25.2 |
# downloaded March 18, 2021 |
# 61,110 records

# %%
# EXTRACT: Optional third data file import into jupyter notebook (Remember to Change These According to the Path)
# Read O*NET skills data file and store into Pandas DataFrames

skills_df = pd.read_csv('./Resources/skills.txt', delimiter='\t')
skills_df
# Out:
#       O*NET-SOC Code Element ID                       Element Name Scale ID  \
# 0         11-1011.00    2.A.1.a              Reading Comprehension       IM
# 1         11-1011.00    2.A.1.a              Reading Comprehension       LV
# 2         11-1011.00    2.A.1.b                   Active Listening       IM
# 3         11-1011.00    2.A.1.b                   Active Listening       LV
# 4         11-1011.00    2.A.1.c                            Writing       IM
# ...              ...        ...                                ...      ...
# 61105     53-7121.00    2.B.5.b  Management of Financial Resources       LV
# 61106     53-7121.00    2.B.5.c   Management of Material Resources       IM
# 61107     53-7121.00    2.B.5.c   Management of Material Resources       LV
# 61108     53-7121.00    2.B.5.d  Management of Personnel Resources       IM
# 61109     53-7121.00    2.B.5.d  Management of Personnel Resources       LV
#
#        Data Value    N  Standard Error  Lower CI Bound  Upper CI Bound  \
# 0            4.12  8.0            0.13            3.88            4.37
# 1            4.75  8.0            0.16            4.43            5.07
# 2            4.12  8.0            0.13            3.88            4.37
# 3            4.88  8.0            0.23            4.43            5.32
# 4            4.00  8.0            0.00            4.00            4.00
# ...           ...  ...             ...             ...             ...
# 61105        1.12  8.0            0.13            0.88            1.37
# 61106        2.00  8.0            0.00            2.00            2.00
# 61107        1.88  8.0            0.13            1.63            2.12
# 61108        2.88  8.0            0.13            2.63            3.12
# 61109        2.75  8.0            0.16            2.43            3.07
#
#       Recommend Suppress Not Relevant     Date Domain Source
# 0                      N          NaN  07/2014       Analyst
# 1                      N            N  07/2014       Analyst
# 2                      N          NaN  07/2014       Analyst
# 3                      N            N  07/2014       Analyst
# 4                      N          NaN  07/2014       Analyst
# ...                  ...          ...      ...           ...
# 61105                  N            N  08/2019       Analyst
# 61106                  N          NaN  08/2019       Analyst
# 61107                  N            N  08/2019       Analyst
# 61108                  N          NaN  08/2019       Analyst
# 61109                  N            N  08/2019       Analyst
#
# [61110 rows x 13 columns]

# %%
# TRANSFORM: Begin the process of cleaning the data
# Drop the columns that I will not use, keep the rest

skills_df = skills_df.drop(columns = {'N', 'Standard Error', 'Lower CI Bound', 'Upper CI Bound', 
                                     'Recommend Suppress', 'Not Relevant', 'Domain Source'})
skills_df
# Out:
#       O*NET-SOC Code Element ID                       Element Name Scale ID  \
# 0         11-1011.00    2.A.1.a              Reading Comprehension       IM
# 1         11-1011.00    2.A.1.a              Reading Comprehension       LV
# 2         11-1011.00    2.A.1.b                   Active Listening       IM
# 3         11-1011.00    2.A.1.b                   Active Listening       LV
# 4         11-1011.00    2.A.1.c                            Writing       IM
# ...              ...        ...                                ...      ...
# 61105     53-7121.00    2.B.5.b  Management of Financial Resources       LV
# 61106     53-7121.00    2.B.5.c   Management of Material Resources       IM
# 61107     53-7121.00    2.B.5.c   Management of Material Resources       LV
# 61108     53-7121.00    2.B.5.d  Management of Personnel Resources       IM
# 61109     53-7121.00    2.B.5.d  Management of Personnel Resources       LV
#
#        Data Value     Date
# 0            4.12  07/2014
# 1            4.75  07/2014
# 2            4.12  07/2014
# 3            4.88  07/2014
# 4            4.00  07/2014
# ...           ...      ...
# 61105        1.12  08/2019
# 61106        2.00  08/2019
# 61107        1.88  08/2019
# 61108        2.88  08/2019
# 61109        2.75  08/2019
#
# [61110 rows x 6 columns]

# %%
# If I want to merge this data set with the SOC, transform the O*NET-SOC Code without the .00

test1_df = skills_df["O*NET-SOC Code"].str.split(".", n=1, expand = True)

# %%
skills_df["onet_soc_code"]= test1_df[0]
skills_df.head()
# Out:
#   O*NET-SOC Code Element ID           Element Name Scale ID  Data Value  \
# 0     11-1011.00    2.A.1.a  Reading Comprehension       IM        4.12
# 1     11-1011.00    2.A.1.a  Reading Comprehension       LV        4.75
# 2     11-1011.00    2.A.1.b       Active Listening       IM        4.12
# 3     11-1011.00    2.A.1.b       Active Listening       LV        4.88
# 4     11-1011.00    2.A.1.c                Writing       IM        4.00
#
#       Date onet_soc_code
# 0  07/2014       11-1011
# 1  07/2014       11-1011
# 2  07/2014       11-1011
# 3  07/2014       11-1011
# 4  07/2014       11-1011

# %%
# Drop the old O*NET-SOC Code once the split and new attribute was created

skills_df.drop(columns = 'O*NET-SOC Code', inplace = True)
skills_df.head()
# Out:
#   Element ID           Element Name Scale ID  Data Value     Date  \
# 0    2.A.1.a  Reading Comprehension       IM        4.12  07/2014
# 1    2.A.1.a  Reading Comprehension       LV        4.75  07/2014
# 2    2.A.1.b       Active Listening       IM        4.12  07/2014
# 3    2.A.1.b       Active Listening       LV        4.88  07/2014
# 4    2.A.1.c                Writing       IM        4.00  07/2014
#
#   onet_soc_code
# 0       11-1011
# 1       11-1011
# 2       11-1011
# 3       11-1011
# 4       11-1011

# %%
# Preference to rename the attributes to snake format

skills_df = skills_df.rename(columns = {'Element ID':'skills_id', 'Element Name':'skills_name',
                           'Scale ID':'skills_scale', 'Data Value':'skills_data','Date':'skills_date'})
skills_df.head()
# Out:
#   skills_id            skills_name skills_scale  skills_data skills_date  \
# 0   2.A.1.a  Reading Comprehension           IM         4.12     07/2014
# 1   2.A.1.a  Reading Comprehension           LV         4.75     07/2014
# 2   2.A.1.b       Active Listening           IM         4.12     07/2014
# 3   2.A.1.b       Active Listening           LV         4.88     07/2014
# 4   2.A.1.c                Writing           IM         4.00     07/2014
#
#   onet_soc_code
# 0       11-1011
# 1       11-1011
# 2       11-1011
# 3       11-1011
# 4       11-1011

# %%
# Reorder the columns with onet_soc_code, which will be a primary key across all the data tables

skills_df = skills_df[['onet_soc_code', 'skills_id', 'skills_name', 'skills_scale','skills_data','skills_date']]
skills_df.head()
# Out:
#   onet_soc_code skills_id            skills_name skills_scale  skills_data  \
# 0       11-1011   2.A.1.a  Reading Comprehension           IM         4.12
# 1       11-1011   2.A.1.a  Reading Comprehension           LV         4.75
# 2       11-1011   2.A.1.b       Active Listening           IM         4.12
# 3       11-1011   2.A.1.b       Active Listening           LV         4.88
# 4       11-1011   2.A.1.c                Writing           IM         4.00
#
#   skills_date
# 0     07/2014
# 1     07/2014
# 2     07/2014
# 3     07/2014
# 4     07/2014

# %%
skills_df.dtypes
# Out:
# onet_soc_code     object
# skills_id         object
# skills_name       object
# skills_scale      object
# skills_data      float64
# skills_date       object
# dtype: object

# %% [markdown]
# ## Create a SQL Schema
# The roadmap of where the data will be loaded into Postgresql. I created a Entity Relationship Diagram (ERD) of my schema and took a snapshot. I also pasted the code below from postgresql:
#
# ```sql
# CREATE TABLE skills(
# 	onet_soc_code VARCHAR NOT NULL,
# 	skills_id VARCHAR,
# 	skills_name TEXT,
# 	skills_scale VARCHAR,
# 	skills_data FLOAT,
# 	skills_date DATE,
# 	PRIMARY KEY(onet_soc_code)
# );
#
# CREATE TABLE detailed_soc(
# 	soc_code VARCHAR NOT NULL,
# 	detailed_title TEXT,
# 	definition TEXT,
# 	FOREIGN KEY(soc_code) REFERENCES skills(onet_soc_code),
# 	PRIMARY KEY(soc_code)
# );
#
# CREATE TABLE ed(
# 	onet_soc_code VARCHAR NOT NULL,
# 	ed_id VARCHAR,
# 	ed_name TEXT,
# 	ed_scale VARCHAR,
# 	ed_data FLOAT,
# 	ed_date DATE,
# 	FOREIGN KEY(onet_soc_code) REFERENCES detailed_soc(soc_code),
# 	PRIMARY KEY(onet_soc_code)
# );
#
# CREATE TABLE major_soc(
# 	soc_code VARCHAR NOT NULL,
# 	major_title TEXT,
# 	PRIMARY KEY(soc_code)
# );
#
# CREATE TABLE minor_soc(
# 	soc_code VARCHAR NOT NULL,
# 	minor_title TEXT,
# 	PRIMARY KEY(soc_code)
# );
#
# CREATE TABLE broad_soc(
# 	soc_code VARCHAR NOT NULL,
# 	minor_title TEXT,
# 	PRIMARY KEY(soc_code)
# );
# ```

# %%
# Connect to the database (db)
from server import server

engine = create_engine(server)
conn = engine.connect()
print(engine)
print(engine.table_names())
# Out:
# Engine(postgresql://postgres:***@localhost:5432/etl)
# ['ed', 'skills', 'detailed_soc', 'major_soc', 'broad_soc', 'minor_soc']

# %% [markdown]
# ## LOADING
# Use pandas to load converted .xlsx and .txt files to Dataframe into Postgresql Dataframe

# %%
detailed_soc_df.to_sql(name="detailed_soc", con=engine, if_exists="append", index=False)

# %%
skills_df.to_sql(name="skills", con=engine, if_exists="append", index=False)

# %%
ed_df.to_sql(name="ed", con=engine, if_exists="append", index=False)

# %%
major_soc_df.to_sql(name="major_soc", con=engine, if_exists="append", index=False)

# %%
broad_soc_df.to_sql(name="broad_soc", con=engine, if_exists="append", index=False)

# %%
minor_soc_df.to_sql(name="minor_soc", con=engine, if_exists="append", index=False)
